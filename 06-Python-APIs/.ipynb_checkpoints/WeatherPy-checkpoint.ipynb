# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 592

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create lists to append information pulled 
cities_found = []
lat = []
long = []
temp = []
humidity = []
cloud = []
speed = []

# Set url to include API key
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# Set counters to be used for the print statements
counter = 0
set_count = 1

print("Beginning Data Retrieval")
print("-----------------------------")

# Perform queries for elements in the cities list, and append them to others lists to be used in dataframe
for city in cities:
    
    try:
        response = requests.get(f"{url}&q={city}").json() 
        cities_found.append(response["name"])
        lat.append(response["coord"]["lat"])
        long.append(response["coord"]["lon"])
        temp.append(response["main"]["temp"])
        humidity.append(response["main"]["humidity"])
        cloud.append(response["clouds"]["all"])
        speed.append(response["wind"]["speed"])
        
        if counter > 49:      # When the counter prints 50 or above
            counter = 1       # Start the counter at 1 again
            set_count += 1    # Set count is the last set count + 1 and exit the set
        else:
            counter += 1      # When the counter is less than 50, keep adding to counter
        
        print(f"Processing Record {counter} of Set {set_count} | {city}")

          
    except:
        print("City not found. Skipping...")
    continue
    
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | severo-kurilsk
# Processing Record 3 of Set 1 | adre
# Processing Record 4 of Set 1 | ust-koksa
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | iqaluit
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | nsanje
# Processing Record 10 of Set 1 | barrow
# Processing Record 11 of Set 1 | prado
# Processing Record 12 of Set 1 | tiksi
# City not found. Skipping...
# Processing Record 13 of Set 1 | saint george
# Processing Record 14 of Set 1 | wuwei
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | nanortalik
# Processing Record 17 of Set 1 | geraldton
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | camocim
# Processing Record 21 of Set 1 | kralendijk
# Processing Record 22 of Set 1 | lumeje
# Processing Record 23 of Set 1 | kpandae
# Processing Record 24 of Set 1 | port hardy
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | cabo san lucas
# Processing Record 27 of Set 1 | gorshechnoye
# Processing Record 28 of Set 1 | muscat
# Processing Record 29 of Set 1 | ushtobe
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | ambanja
# Processing Record 32 of Set 1 | ayan
# City not found. Skipping...
# Processing Record 33 of Set 1 | athabasca
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | eureka
# Processing Record 36 of Set 1 | upernavik
# Processing Record 37 of Set 1 | guerrero negro
# Processing Record 38 of Set 1 | jishu
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | butaritari
# Processing Record 41 of Set 1 | aykhal
# Processing Record 42 of Set 1 | tieling
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | vila velha
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | sambava
# Processing Record 47 of Set 1 | venice
# Processing Record 48 of Set 1 | fortuna
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 1 of Set 2 | adeje
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | chicama
# Processing Record 4 of Set 2 | bubaque
# Processing Record 5 of Set 2 | belmonte
# City not found. Skipping...
# Processing Record 6 of Set 2 | punta cardon
# Processing Record 7 of Set 2 | ixtapa
# Processing Record 8 of Set 2 | mahina
# Processing Record 9 of Set 2 | port alfred
# Processing Record 10 of Set 2 | kaitangata
# Processing Record 11 of Set 2 | new norfolk
# Processing Record 12 of Set 2 | cayenne
# Processing Record 13 of Set 2 | kloulklubed
# Processing Record 14 of Set 2 | yellowknife
# Processing Record 15 of Set 2 | puerto leguizamo
# Processing Record 16 of Set 2 | torbay
# Processing Record 17 of Set 2 | pontianak
# Processing Record 18 of Set 2 | nogliki
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | awjilah
# Processing Record 21 of Set 2 | hilo
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | victoria
# Processing Record 24 of Set 2 | puerto ayora
# Processing Record 25 of Set 2 | chokurdakh
# Processing Record 26 of Set 2 | necochea
# Processing Record 27 of Set 2 | huarmey
# Processing Record 28 of Set 2 | shatki
# City not found. Skipping...
# Processing Record 29 of Set 2 | correntina
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | la reforma
# Processing Record 32 of Set 2 | pasni
# Processing Record 33 of Set 2 | lacaron
# City not found. Skipping...
# Processing Record 34 of Set 2 | marzuq
# Processing Record 35 of Set 2 | dudinka
# Processing Record 36 of Set 2 | kajaani
# Processing Record 37 of Set 2 | hasaki
# Processing Record 38 of Set 2 | betsiamites
# Processing Record 39 of Set 2 | strezhevoy
# Processing Record 40 of Set 2 | saint-pierre
# Processing Record 41 of Set 2 | moerai
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 2 | khatanga
# City not found. Skipping...
# Processing Record 43 of Set 2 | chengde
# Processing Record 44 of Set 2 | padang
# Processing Record 45 of Set 2 | port blair
# Processing Record 46 of Set 2 | pacific grove
# Processing Record 47 of Set 2 | boke
# Processing Record 48 of Set 2 | isangel
# Processing Record 49 of Set 2 | georgetown
# Processing Record 50 of Set 2 | huanren
# Processing Record 1 of Set 3 | saldanha
# City not found. Skipping...
# Processing Record 2 of Set 3 | cairns
# Processing Record 3 of Set 3 | luan
# Processing Record 4 of Set 3 | clonakilty
# Processing Record 5 of Set 3 | guerande
# Processing Record 6 of Set 3 | coihaique
# Processing Record 7 of Set 3 | luderitz
# Processing Record 8 of Set 3 | avera
# Processing Record 9 of Set 3 | richards bay
# Processing Record 10 of Set 3 | emerald
# Processing Record 11 of Set 3 | zheleznodorozhnyy
# Processing Record 12 of Set 3 | acapulco
# Processing Record 13 of Set 3 | cidreira
# Processing Record 14 of Set 3 | vangaindrano
# Processing Record 15 of Set 3 | bilma
# Processing Record 16 of Set 3 | jamestown
# Processing Record 17 of Set 3 | safford
# Processing Record 18 of Set 3 | ratanpur
# Processing Record 19 of Set 3 | hope
# Processing Record 20 of Set 3 | karlshamn
# City not found. Skipping...
# Processing Record 21 of Set 3 | zhigansk
# Processing Record 22 of Set 3 | mhango
# Processing Record 23 of Set 3 | mana
# Processing Record 24 of Set 3 | bellevue
# Processing Record 25 of Set 3 | hofn
# Processing Record 26 of Set 3 | longyearbyen
# Processing Record 27 of Set 3 | port shepstone
# Processing Record 28 of Set 3 | airai
# Processing Record 29 of Set 3 | san luis
# Processing Record 30 of Set 3 | zhanaozen
# Processing Record 31 of Set 3 | biskamzha
# Processing Record 32 of Set 3 | san francisco
# Processing Record 33 of Set 3 | abonnema
# Processing Record 34 of Set 3 | port hedland
# Processing Record 35 of Set 3 | husavik
# Processing Record 36 of Set 3 | provideniya
# Processing Record 37 of Set 3 | avarua
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of Set 3 | tecoanapa
# Processing Record 39 of Set 3 | dikson
# Processing Record 40 of Set 3 | saiha
# Processing Record 41 of Set 3 | mitzic
# City not found. Skipping...
# Processing Record 42 of Set 3 | bethel
# Processing Record 43 of Set 3 | aklavik
# Processing Record 44 of Set 3 | qaanaaq
# Processing Record 45 of Set 3 | shimoda
# Processing Record 46 of Set 3 | hambantota
# Processing Record 47 of Set 3 | nikolskoye
# Processing Record 48 of Set 3 | saint-philippe
# Processing Record 49 of Set 3 | haines junction
# Processing Record 50 of Set 3 | goderich
# Processing Record 1 of Set 4 | akbarpur
# Processing Record 2 of Set 4 | ilulissat
# Processing Record 3 of Set 4 | grindavik
# Processing Record 4 of Set 4 | codrington
# Processing Record 5 of Set 4 | hirara
# Processing Record 6 of Set 4 | sao gabriel da cachoeira
# Processing Record 7 of Set 4 | bluefields
# City not found. Skipping...
# Processing Record 8 of Set 4 | naze
# Processing Record 9 of Set 4 | sola
# Processing Record 10 of Set 4 | boca do acre
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 4 | vanavara
# Processing Record 12 of Set 4 | savonlinna
# Processing Record 13 of Set 4 | norman wells
# Processing Record 14 of Set 4 | cartagena
# Processing Record 15 of Set 4 | lagoa
# Processing Record 16 of Set 4 | srednekolymsk
# Processing Record 17 of Set 4 | pevek
# Processing Record 18 of Set 4 | la asuncion
# Processing Record 19 of Set 4 | iquique
# Processing Record 20 of Set 4 | san cristobal
# City not found. Skipping...
# Processing Record 21 of Set 4 | inuvik
# Processing Record 22 of Set 4 | mar del plata
# Processing Record 23 of Set 4 | banda aceh
# Processing Record 24 of Set 4 | yulara
# Processing Record 25 of Set 4 | kirakira
# Processing Record 26 of Set 4 | nuristan
# City not found. Skipping...
# Processing Record 27 of Set 4 | thompson
# Processing Record 28 of Set 4 | lavrentiya
# City not found. Skipping...
# Processing Record 29 of Set 4 | flin flon
# Processing Record 30 of Set 4 | posadas
# Processing Record 31 of Set 4 | california city
# Processing Record 32 of Set 4 | mantua
# Processing Record 33 of Set 4 | sorland
# Processing Record 34 of Set 4 | lorengau
# Processing Record 35 of Set 4 | wattegama
# Processing Record 36 of Set 4 | porto velho
# Processing Record 37 of Set 4 | mareeba
# Processing Record 38 of Set 4 | yar-sale
# Processing Record 39 of Set 4 | loreto
# Processing Record 40 of Set 4 | mbeya
# Processing Record 41 of Set 4 | cherskiy
# Processing Record 42 of Set 4 | penzance
# Processing Record 43 of Set 4 | kiunga
# Processing Record 44 of Set 4 | ribeira grande
# Processing Record 45 of Set 4 | pesqueria
# Processing Record 46 of Set 4 | santa maria
# Processing Record 47 of Set 4 | ucar
# Processing Record 48 of Set 4 | vardo
# Processing Record 49 of Set 4 | adrar
# Processing Record 50 of Set 4 | arraial do cabo
# Processing Record 1 of Set 5 | saint-francois
# Processing Record 2 of Set 5 | tarakan
# Processing Record 3 of Set 5 | lompoc
# Processing Record 4 of Set 5 | aden
# Processing Record 5 of Set 5 | carutapera
# Processing Record 6 of Set 5 | kruisfontein
# Processing Record 7 of Set 5 | sincelejo
# Processing Record 8 of Set 5 | juba
# Processing Record 9 of Set 5 | pergamino
# Processing Record 10 of Set 5 | buraydah
# Processing Record 11 of Set 5 | lata
# Processing Record 12 of Set 5 | camacupa
# Processing Record 13 of Set 5 | coquimbo
# Processing Record 14 of Set 5 | alepe
# Processing Record 15 of Set 5 | kimbe
# Processing Record 16 of Set 5 | sur
# Processing Record 17 of Set 5 | valdosta
# Processing Record 18 of Set 5 | bhainsa
# Processing Record 19 of Set 5 | makushino
# Processing Record 20 of Set 5 | vryburg
# Processing Record 21 of Set 5 | deputatskiy
# Processing Record 22 of Set 5 | east london
# Processing Record 23 of Set 5 | pizarro
# Processing Record 24 of Set 5 | nemuro
# Processing Record 25 of Set 5 | meulaboh
# City not found. Skipping...
# Processing Record 26 of Set 5 | torbat-e jam
# Processing Record 27 of Set 5 | okhotsk
# Processing Record 28 of Set 5 | narsaq
# Processing Record 29 of Set 5 | kodiak
# Processing Record 30 of Set 5 | sarangani
# Processing Record 31 of Set 5 | faanui
# Processing Record 32 of Set 5 | japura
# Processing Record 33 of Set 5 | samaipata
# Processing Record 34 of Set 5 | mut
# Processing Record 35 of Set 5 | nerchinskiy zavod
# Processing Record 36 of Set 5 | chuy
# Processing Record 37 of Set 5 | bako
# Processing Record 38 of Set 5 | kahului
# Processing Record 39 of Set 5 | concordia
# Processing Record 40 of Set 5 | rawson
# Processing Record 41 of Set 5 | kommunisticheskiy
# City not found. Skipping...
# Processing Record 42 of Set 5 | saskylakh
# Processing Record 43 of Set 5 | atambua
# Processing Record 44 of Set 5 | mahebourg
# Processing Record 45 of Set 5 | port-gentil
# Processing Record 46 of Set 5 | tungor
# City not found. Skipping...
# Processing Record 47 of Set 5 | sokolo
# Processing Record 48 of Set 5 | bamako
# Processing Record 49 of Set 5 | maumere
# Processing Record 50 of Set 5 | matamoros
# Processing Record 1 of Set 6 | vila franca do campo
# Processing Record 2 of Set 6 | tessalit
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of Set 6 | lubao
# Processing Record 4 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 6 | port elizabeth
# Processing Record 6 of Set 6 | itarema
# Processing Record 7 of Set 6 | samfya
# Processing Record 8 of Set 6 | tazovskiy
# City not found. Skipping...
# Processing Record 9 of Set 6 | tefe
# Processing Record 10 of Set 6 | kaeo
# Processing Record 11 of Set 6 | ponta do sol
# Processing Record 12 of Set 6 | antalaha
# Processing Record 13 of Set 6 | mabopane
# City not found. Skipping...
# Processing Record 14 of Set 6 | verkhnevilyuysk
# Processing Record 15 of Set 6 | mildura
# Processing Record 16 of Set 6 | yagodnoye
# Processing Record 17 of Set 6 | tuatapere
# Processing Record 18 of Set 6 | oranjemund
# Processing Record 19 of Set 6 | talnakh
# Processing Record 20 of Set 6 | maldonado
# Processing Record 21 of Set 6 | sovetskiy
# Processing Record 22 of Set 6 | lampa
# Processing Record 23 of Set 6 | ovsyanka
# Processing Record 24 of Set 6 | kavieng
# Processing Record 25 of Set 6 | koslan
# Processing Record 26 of Set 6 | mnogovershinnyy
# Processing Record 27 of Set 6 | turtas
# Processing Record 28 of Set 6 | darnah
# Processing Record 29 of Set 6 | halifax
# Processing Record 30 of Set 6 | alofi
# Processing Record 31 of Set 6 | deniliquin
# Processing Record 32 of Set 6 | kadaya
# Processing Record 33 of Set 6 | kettering
# Processing Record 34 of Set 6 | mayuge
# Processing Record 35 of Set 6 | ancud
# Processing Record 36 of Set 6 | fort nelson
# Processing Record 37 of Set 6 | muli
# Processing Record 38 of Set 6 | bonavista
# Processing Record 39 of Set 6 | barreirinha
# Processing Record 40 of Set 6 | toora-khem
# Processing Record 41 of Set 6 | snezhnogorsk
# Processing Record 42 of Set 6 | komsomolskiy
# City not found. Skipping...
# Processing Record 43 of Set 6 | sao filipe
# Processing Record 44 of Set 6 | pauini
# City not found. Skipping...
# Processing Record 45 of Set 6 | te anau
# Processing Record 46 of Set 6 | olga
# Processing Record 47 of Set 6 | leiyang
# City not found. Skipping...
# Processing Record 48 of Set 6 | leningradskiy
# Processing Record 49 of Set 6 | lahij
# Processing Record 50 of Set 6 | road town
# Processing Record 1 of Set 7 | chaohu
# Processing Record 2 of Set 7 | hudiksvall
# Processing Record 3 of Set 7 | tianpeng
# Processing Record 4 of Set 7 | smardan
# Processing Record 5 of Set 7 | baculin
# Processing Record 6 of Set 7 | clyde river
# Processing Record 7 of Set 7 | gbarnga
# Processing Record 8 of Set 7 | klaksvik
# Processing Record 9 of Set 7 | laguna
# Processing Record 10 of Set 7 | moose factory
# Processing Record 11 of Set 7 | zhoucheng
# Processing Record 12 of Set 7 | paamiut
# Processing Record 13 of Set 7 | roebourne
# City not found. Skipping...
# Processing Record 14 of Set 7 | avallon
# Processing Record 15 of Set 7 | quatre cocos
# Processing Record 16 of Set 7 | franklin
# Processing Record 17 of Set 7 | sept-iles
# Processing Record 18 of Set 7 | amuntai
# Processing Record 19 of Set 7 | kenora
# Processing Record 20 of Set 7 | lebanon
# Processing Record 21 of Set 7 | drumnadrochit
# Processing Record 22 of Set 7 | yaan
# Processing Record 23 of Set 7 | cap-aux-meules
# Processing Record 24 of Set 7 | alamogordo
# Processing Record 25 of Set 7 | mirabela
# Processing Record 26 of Set 7 | mirnyy
# Processing Record 27 of Set 7 | marawi
# City not found. Skipping...
# Processing Record 28 of Set 7 | hokitika
# Processing Record 29 of Set 7 | hami
# Processing Record 30 of Set 7 | kasongo-lunda
# Processing Record 31 of Set 7 | maningrida
# Processing Record 32 of Set 7 | tira sujanpur
# Processing Record 33 of Set 7 | sao jose de ribamar
# Processing Record 34 of Set 7 | matiri
# Processing Record 35 of Set 7 | alice springs
# Processing Record 36 of Set 7 | dunedin
# Processing Record 37 of Set 7 | marrakesh
# Processing Record 38 of Set 7 | arlit
# Processing Record 39 of Set 7 | auch
# Processing Record 40 of Set 7 | xinqing
# Processing Record 41 of Set 7 | caravelas
# Processing Record 42 of Set 7 | tezu
# Processing Record 43 of Set 7 | wellington
# Processing Record 44 of Set 7 | halvad
# Processing Record 45 of Set 7 | saint anthony
# Processing Record 46 of Set 7 | benghazi
# Processing Record 47 of Set 7 | ordynskoye
# Processing Record 48 of Set 7 | samarai
# City not found. Skipping...
# Processing Record 49 of Set 7 | caninde de sao francisco
# Processing Record 50 of Set 7 | bambous virieux
# City not found. Skipping...
# Processing Record 1 of Set 8 | kavaratti
# Processing Record 2 of Set 8 | rio grande
# Processing Record 3 of Set 8 | maltahohe
# Processing Record 4 of Set 8 | la ronge
# Processing Record 5 of Set 8 | nantucket
# Processing Record 6 of Set 8 | almaty
# Processing Record 7 of Set 8 | frutal
# Processing Record 8 of Set 8 | tornio
# Processing Record 9 of Set 8 | vari
# Processing Record 10 of Set 8 | yendi
# Processing Record 11 of Set 8 | nome
# Processing Record 12 of Set 8 | inongo
# Processing Record 13 of Set 8 | noumea
# Processing Record 14 of Set 8 | labuan
# Processing Record 15 of Set 8 | terme
# Processing Record 16 of Set 8 | vanimo
# Processing Record 17 of Set 8 | moa
# Processing Record 18 of Set 8 | novyy urengoy
# Processing Record 19 of Set 8 | makakilo city
# Processing Record 20 of Set 8 | gersthofen
# Processing Record 21 of Set 8 | souillac
# Processing Record 22 of Set 8 | ambilobe
# Processing Record 23 of Set 8 | port macquarie
# Processing Record 24 of Set 8 | kilindoni
# City not found. Skipping...
# Processing Record 25 of Set 8 | diebougou
# City not found. Skipping...
# Processing Record 26 of Set 8 | chernyshevskiy
# Processing Record 27 of Set 8 | kadoma
# Processing Record 28 of Set 8 | velasco ibarra
# Processing Record 29 of Set 8 | port hawkesbury
# Processing Record 30 of Set 8 | naryan-mar
# City not found. Skipping...
# Processing Record 31 of Set 8 | sumbe
# Processing Record 32 of Set 8 | chara
# Processing Record 33 of Set 8 | beira
# Processing Record 34 of Set 8 | zonguldak
# Processing Record 35 of Set 8 | tapalpa
# Processing Record 36 of Set 8 | sultanpur
# Processing Record 37 of Set 8 | castro
# Processing Record 38 of Set 8 | christchurch
# Processing Record 39 of Set 8 | mount gambier
# Processing Record 40 of Set 8 | tabu
# Processing Record 41 of Set 8 | phan thiet
# Processing Record 42 of Set 8 | sisimiut
# City not found. Skipping...
# Processing Record 43 of Set 8 | hovd
# Processing Record 44 of Set 8 | hillsborough
# Processing Record 45 of Set 8 | harper
# Processing Record 46 of Set 8 | petrolina
# Processing Record 47 of Set 8 | lima
# Processing Record 48 of Set 8 | kafanchan
# Processing Record 49 of Set 8 | koumac
# Processing Record 50 of Set 8 | gorele
# Processing Record 1 of Set 9 | tabou
# Processing Record 2 of Set 9 | tutoia
# Processing Record 3 of Set 9 | singaraja
# Processing Record 4 of Set 9 | hobyo
# Processing Record 5 of Set 9 | esperance
# Processing Record 6 of Set 9 | muros
# Processing Record 7 of Set 9 | atar
# Processing Record 8 of Set 9 | kamen-rybolov
# Processing Record 9 of Set 9 | eyl
# Processing Record 10 of Set 9 | karratha
# Processing Record 11 of Set 9 | bay roberts
# City not found. Skipping...
# Processing Record 12 of Set 9 | zaysan
# Processing Record 13 of Set 9 | ostrovnoy
# Processing Record 14 of Set 9 | galveston
# Processing Record 15 of Set 9 | wapi pathum
# Processing Record 16 of Set 9 | merauke
# Processing Record 17 of Set 9 | luwuk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of Set 9 | udachnyy
# Processing Record 19 of Set 9 | belle fourche
# Processing Record 20 of Set 9 | sao joao da barra
# Processing Record 21 of Set 9 | barranquilla
# Processing Record 22 of Set 9 | kayerkan
# Processing Record 23 of Set 9 | valdemarpils
# Processing Record 24 of Set 9 | san rafael
# Processing Record 25 of Set 9 | port lincoln
# Processing Record 26 of Set 9 | pangnirtung
# Processing Record 27 of Set 9 | cap malheureux
# Processing Record 28 of Set 9 | dakar
# Processing Record 29 of Set 9 | chirilagua
# City not found. Skipping...
# Processing Record 30 of Set 9 | salalah
# Processing Record 31 of Set 9 | bahia blanca
# Processing Record 32 of Set 9 | saint-leu
# Processing Record 33 of Set 9 | ippy
# Processing Record 34 of Set 9 | tanout
# Processing Record 35 of Set 9 | boende
# Processing Record 36 of Set 9 | orocue
# Processing Record 37 of Set 9 | algiers
# Processing Record 38 of Set 9 | vrangel
# Processing Record 39 of Set 9 | dali
# Processing Record 40 of Set 9 | qaqortoq
# Processing Record 41 of Set 9 | piacabucu
# Processing Record 42 of Set 9 | manicore
# Processing Record 43 of Set 9 | labuhan
# Processing Record 44 of Set 9 | malindi
# Processing Record 45 of Set 9 | limbazi
# Processing Record 46 of Set 9 | ponazyrevo
# Processing Record 47 of Set 9 | hit
# Processing Record 48 of Set 9 | palmer
# Processing Record 49 of Set 9 | kalangala
# Processing Record 50 of Set 9 | pucara
# Processing Record 1 of Set 10 | guozhen
# Processing Record 2 of Set 10 | warmbad
# Processing Record 3 of Set 10 | taraz
# Processing Record 4 of Set 10 | lai
# Processing Record 5 of Set 10 | kuito
# Processing Record 6 of Set 10 | dalbandin
# Processing Record 7 of Set 10 | cravo norte
# Processing Record 8 of Set 10 | salta
# Processing Record 9 of Set 10 | la cruz
# Processing Record 10 of Set 10 | dessau
# Processing Record 11 of Set 10 | mae hong son
# Processing Record 12 of Set 10 | basoko
# Processing Record 13 of Set 10 | taonan
# Processing Record 14 of Set 10 | erzin
# Processing Record 15 of Set 10 | condega
# Processing Record 16 of Set 10 | mchinji
# Processing Record 17 of Set 10 | kokopo
# Processing Record 18 of Set 10 | flinders
# Processing Record 19 of Set 10 | shingu
# Processing Record 20 of Set 10 | kutum
# Processing Record 21 of Set 10 | salinas
# Processing Record 22 of Set 10 | dundee
# Processing Record 23 of Set 10 | bridlington
# Processing Record 24 of Set 10 | ukiah
# City not found. Skipping...
# Processing Record 25 of Set 10 | ekibastuz
# Processing Record 26 of Set 10 | daru
# Processing Record 27 of Set 10 | sinnamary
# Processing Record 28 of Set 10 | santa cruz
# Processing Record 29 of Set 10 | cockburn town
# Processing Record 30 of Set 10 | bjornevatn
# Processing Record 31 of Set 10 | kohima
# Processing Record 32 of Set 10 | tura
# Processing Record 33 of Set 10 | bandarbeyla
# Processing Record 34 of Set 10 | seversk
# Processing Record 35 of Set 10 | madisonville
# Processing Record 36 of Set 10 | vega de alatorre
# Processing Record 37 of Set 10 | qovlar
# Processing Record 38 of Set 10 | lixourion
# Processing Record 39 of Set 10 | lienz
# Processing Record 40 of Set 10 | mitsamiouli
# Processing Record 41 of Set 10 | rocha
# City not found. Skipping...
# Processing Record 42 of Set 10 | kilifarevo
# City not found. Skipping...
# Processing Record 43 of Set 10 | hermosillo
# Processing Record 44 of Set 10 | constantine
# Processing Record 45 of Set 10 | chernogorsk
# Processing Record 46 of Set 10 | oskarshamn
# Processing Record 47 of Set 10 | moindou
# Processing Record 48 of Set 10 | yakeshi
# Processing Record 49 of Set 10 | sheridan
# Processing Record 50 of Set 10 | teguise
# Processing Record 1 of Set 11 | kapustin yar
# Processing Record 2 of Set 11 | waddan
# Processing Record 3 of Set 11 | san quintin
# Processing Record 4 of Set 11 | taybad
# Processing Record 5 of Set 11 | statesboro
# Processing Record 6 of Set 11 | manaure
# Processing Record 7 of Set 11 | manga
# Processing Record 8 of Set 11 | rajanpur
# Processing Record 9 of Set 11 | nabire
# Processing Record 10 of Set 11 | havoysund
# Processing Record 11 of Set 11 | tak
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 12 of Set 11 | breves
# Processing Record 13 of Set 11 | amahai
# Processing Record 14 of Set 11 | itupiranga
# City not found. Skipping...
# Processing Record 15 of Set 11 | lafiagi
# Processing Record 16 of Set 11 | zhuhai
# Processing Record 17 of Set 11 | jardim
# Processing Record 18 of Set 11 | carrboro
# Processing Record 19 of Set 11 | havre-saint-pierre
# Processing Record 20 of Set 11 | tra vinh
# Processing Record 21 of Set 11 | oswiecim
# Processing Record 22 of Set 11 | yuncheng
# Processing Record 23 of Set 11 | poum
# Processing Record 24 of Set 11 | sayansk
# Processing Record 25 of Set 11 | natal
# Processing Record 26 of Set 11 | turukhansk
# Processing Record 27 of Set 11 | yunyang
# Processing Record 28 of Set 11 | gat
# Processing Record 29 of Set 11 | whitianga
# Processing Record 30 of Set 11 | belyy yar
# City not found. Skipping...
# Processing Record 31 of Set 11 | college
# Processing Record 32 of Set 11 | tarnogskiy gorodok
# Processing Record 33 of Set 11 | panguna
# Processing Record 34 of Set 11 | gusau
# Processing Record 35 of Set 11 | umm kaddadah
# City not found. Skipping...
# Processing Record 36 of Set 11 | manta
# Processing Record 37 of Set 11 | kasane
# Processing Record 38 of Set 11 | najran
# Processing Record 39 of Set 11 | beringovskiy
# Processing Record 40 of Set 11 | kamenka
# Processing Record 41 of Set 11 | ketchikan
# Processing Record 42 of Set 11 | kofele
# Processing Record 43 of Set 11 | takaka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df = pd.DataFrame({"City Name" : cities_found,
                "Latitude" : lat,
                "Longitude" : long,
                "Temperature" : temp,
                "Humidity" : humidity,
                "Cloudiness" : cloud,
                "Wind Speend" : speed})
cities_df.head()
# Out:
#         City Name  Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# 0    Punta Arenas    -53.16     -70.91        41.00        76           0
# 1  Severo-Kurilsk     50.68     156.12        45.35        91         100
# 2            Adre     13.47      22.20        86.79        41          38
# 3       Ust-Koksa     50.27      85.62        43.82        29           0
# 4         Rikitea    -23.12    -134.97        67.80        74          36
#
#    Wind Speend
# 0        20.80
# 1        20.09
# 2         1.25
# 3         2.93
# 4        15.52

# %%
cities_df.to_csv(output_data_file, index = False, header = True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
