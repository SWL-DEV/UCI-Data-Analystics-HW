# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 587

# %%
# Create lists to append information pulled 
cities_found = []
lat = []
long = []
temp = []
humidity = []
cloud = []
speed = []

cities_df = pd.DataFrame({"City Name" : cities_found,
                          "Latitude" : lat,
                          "Longitude" : long,
                          "Temperature" : temp,
                          "Humidity" : humidity,
                          "Cloudiness" : cloud,
                          "Wind Speend" : speed})

cities_df
# Out:
# Empty DataFrame
# Columns: [City Name, Latitude, Longitude, Temperature, Humidity, Cloudiness, Wind Speend]
# Index: []

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
counter = 0
set_count = 1

print("Beginning Data Retrieval")
print("-----------------------------")
for city in cities:
    
    try:
        response = requests.get(f"{url}&q={city}").json() 
        cities_found.append(city)
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        speed.append(response['wind']['speed'])
        
#         if counter <= 49:
#             counter += 1
#         else:
#             counter += 1
#             set_count = set_count + 1
#         print(f"Processing Record {counter} of Set {set_count} | {city}")
        
    
        if counter > 49:
            set_count = set_count + 1
        else:
            counter += 1
        print(f"Processing Record {counter} of Set {set_count} | {city}")
        
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | kodiak
# Processing Record 5 of Set 1 | boddam
# Processing Record 6 of Set 1 | akdepe
# Processing Record 7 of Set 1 | torbay
# Processing Record 8 of Set 1 | new norfolk
# City not found. Skipping...
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | georgetown
# Processing Record 11 of Set 1 | riyadh
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | faanui
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | jiblah
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | east london
# Processing Record 23 of Set 1 | provideniya
# Processing Record 24 of Set 1 | hihya
# Processing Record 25 of Set 1 | bambous virieux
# Processing Record 26 of Set 1 | fort-shevchenko
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | mednogorsk
# Processing Record 29 of Set 1 | albany
# Processing Record 30 of Set 1 | kruisfontein
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | landau
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | namibe
# Processing Record 35 of Set 1 | berdigestyakh
# Processing Record 36 of Set 1 | punta arenas
# Processing Record 37 of Set 1 | teluknaga
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | huaihua
# Processing Record 40 of Set 1 | saskylakh
# Processing Record 41 of Set 1 | ponta do sol
# Processing Record 42 of Set 1 | port alfred
# Processing Record 43 of Set 1 | inuvik
# Processing Record 44 of Set 1 | lebu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 1 | ust-kuyga
# Processing Record 46 of Set 1 | thompson
# Processing Record 47 of Set 1 | yershichi
# Processing Record 48 of Set 1 | chuy
# City not found. Skipping...
# Processing Record 49 of Set 1 | nuuk
# Processing Record 50 of Set 1 | victoria
# City not found. Skipping...
# Processing Record 50 of Set 2 | chokurdakh
# Processing Record 50 of Set 3 | cidreira
# Processing Record 50 of Set 4 | thunder bay
# Processing Record 50 of Set 5 | lompoc
# Processing Record 50 of Set 6 | sao felix do xingu
# Processing Record 50 of Set 7 | vaini
# Processing Record 50 of Set 8 | qaanaaq
# Processing Record 50 of Set 9 | lazaro cardenas
# Processing Record 50 of Set 10 | kushiro
# Processing Record 50 of Set 11 | vila
# Processing Record 50 of Set 12 | moengo
# Processing Record 50 of Set 13 | sorong
# City not found. Skipping...
# Processing Record 50 of Set 14 | mount gambier
# City not found. Skipping...
# Processing Record 50 of Set 15 | grindavik
# Processing Record 50 of Set 16 | vestmanna
# Processing Record 50 of Set 17 | bredasdorp
# Processing Record 50 of Set 18 | port lincoln
# Processing Record 50 of Set 19 | bradford
# Processing Record 50 of Set 20 | mora
# Processing Record 50 of Set 21 | kabare
# Processing Record 50 of Set 22 | bay roberts
# Processing Record 50 of Set 23 | kapaa
# Processing Record 50 of Set 24 | kishi
# Processing Record 50 of Set 25 | kavieng
# Processing Record 50 of Set 26 | cape town
# Processing Record 50 of Set 27 | xuddur
# Processing Record 50 of Set 28 | chapais
# Processing Record 50 of Set 29 | santa maria da boa vista
# Processing Record 50 of Set 30 | ca mau
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 31 | tete
# Processing Record 50 of Set 32 | kargopol
# Processing Record 50 of Set 33 | la asuncion
# City not found. Skipping...
# Processing Record 50 of Set 34 | san patricio
# Processing Record 50 of Set 35 | huarmey
# Processing Record 50 of Set 36 | khatanga
# Processing Record 50 of Set 37 | hithadhoo
# Processing Record 50 of Set 38 | vestmannaeyjar
# Processing Record 50 of Set 39 | amahai
# Processing Record 50 of Set 40 | te anau
# Processing Record 50 of Set 41 | sovetskiy
# Processing Record 50 of Set 42 | novonikolayevskaya
# Processing Record 50 of Set 43 | tevaitoa
# Processing Record 50 of Set 44 | pisco
# Processing Record 50 of Set 45 | prainha
# Processing Record 50 of Set 46 | mukhen
# City not found. Skipping...
# Processing Record 50 of Set 47 | puerto ayora
# City not found. Skipping...
# Processing Record 50 of Set 48 | gulbarga
# Processing Record 50 of Set 49 | mercedes
# Processing Record 50 of Set 50 | sinegorye
# Processing Record 50 of Set 51 | hobart
# Processing Record 50 of Set 52 | port keats
# City not found. Skipping...
# Processing Record 50 of Set 53 | truckee
# Processing Record 50 of Set 54 | malanje
# Processing Record 50 of Set 55 | fairbanks
# Processing Record 50 of Set 56 | micheweni
# City not found. Skipping...
# Processing Record 50 of Set 57 | nevsehir
# Processing Record 50 of Set 58 | springbok
# Processing Record 50 of Set 59 | ouesso
# Processing Record 50 of Set 60 | marystown
# Processing Record 50 of Set 61 | santa maria da vitoria
# Processing Record 50 of Set 62 | padang
# Processing Record 50 of Set 63 | yellowknife
# Processing Record 50 of Set 64 | honningsvag
# Processing Record 50 of Set 65 | albion
# Processing Record 50 of Set 66 | hambantota
# City not found. Skipping...
# Processing Record 50 of Set 67 | kedrovyy
# Processing Record 50 of Set 68 | yulara
# Processing Record 50 of Set 69 | tabou
# Processing Record 50 of Set 70 | bethel
# Processing Record 50 of Set 71 | novyy urengoy
# City not found. Skipping...
# Processing Record 50 of Set 72 | goderich
# Processing Record 50 of Set 73 | nioro
# Processing Record 50 of Set 74 | haines junction
# Processing Record 50 of Set 75 | am timan
# Processing Record 50 of Set 76 | cessnock
# Processing Record 50 of Set 77 | mpika
# Processing Record 50 of Set 78 | fort nelson
# Processing Record 50 of Set 79 | yantal
# Processing Record 50 of Set 80 | ulaanbaatar
# Processing Record 50 of Set 81 | ancud
# Processing Record 50 of Set 82 | pundaguitan
# Processing Record 50 of Set 83 | uirauna
# Processing Record 50 of Set 84 | newport
# Processing Record 50 of Set 85 | lichuan
# Processing Record 50 of Set 86 | zhicheng
# Processing Record 50 of Set 87 | port elizabeth
# Processing Record 50 of Set 88 | rock sound
# Processing Record 50 of Set 89 | carutapera
# City not found. Skipping...
# Processing Record 50 of Set 90 | pringsewu
# Processing Record 50 of Set 91 | flin flon
# Processing Record 50 of Set 92 | daru
# Processing Record 50 of Set 93 | oktyabrskoye
# Processing Record 50 of Set 94 | codrington
# Processing Record 50 of Set 95 | baykit
# Processing Record 50 of Set 96 | vardo
# Processing Record 50 of Set 97 | shelburne
# Processing Record 50 of Set 98 | jacmel
# Processing Record 50 of Set 99 | mehamn
# Processing Record 50 of Set 100 | urusha
# Processing Record 50 of Set 101 | havre-saint-pierre
# Processing Record 50 of Set 102 | tuktoyaktuk
# Processing Record 50 of Set 103 | cabo san lucas
# City not found. Skipping...
# Processing Record 50 of Set 104 | airai
# Processing Record 50 of Set 105 | naze
# Processing Record 50 of Set 106 | usinsk
# City not found. Skipping...
# Processing Record 50 of Set 107 | xining
# Processing Record 50 of Set 108 | cherskiy
# Processing Record 50 of Set 109 | ribeira grande
# Processing Record 50 of Set 110 | sambava
# City not found. Skipping...
# Processing Record 50 of Set 111 | ngunguru
# Processing Record 50 of Set 112 | ostashkov
# Processing Record 50 of Set 113 | christchurch
# Processing Record 50 of Set 114 | alofi
# Processing Record 50 of Set 115 | nantucket
# Processing Record 50 of Set 116 | farrukhnagar
# Processing Record 50 of Set 117 | dikson
# City not found. Skipping...
# Processing Record 50 of Set 118 | nanortalik
# Processing Record 50 of Set 119 | east angus
# Processing Record 50 of Set 120 | straumen
# Processing Record 50 of Set 121 | verkhnevilyuysk
# Processing Record 50 of Set 122 | ahipara
# Processing Record 50 of Set 123 | jinchang
# Processing Record 50 of Set 124 | rocha
# Processing Record 50 of Set 125 | kenai
# Processing Record 50 of Set 126 | nyurba
# Processing Record 50 of Set 127 | lagoa
# City not found. Skipping...
# Processing Record 50 of Set 128 | ilulissat
# Processing Record 50 of Set 129 | hervey bay
# Processing Record 50 of Set 130 | gushikawa
# City not found. Skipping...
# Processing Record 50 of Set 131 | kuito
# City not found. Skipping...
# Processing Record 50 of Set 132 | castro
# Processing Record 50 of Set 133 | talnakh
# Processing Record 50 of Set 134 | coihaique
# Processing Record 50 of Set 135 | petatlan
# Processing Record 50 of Set 136 | tuatapere
# Processing Record 50 of Set 137 | vila velha
# Processing Record 50 of Set 138 | arraial do cabo
# Processing Record 50 of Set 139 | dingle
# Processing Record 50 of Set 140 | half moon bay
# Processing Record 50 of Set 141 | lorengau
# Processing Record 50 of Set 142 | faya
# Processing Record 50 of Set 143 | bonavista
# Processing Record 50 of Set 144 | kirakira
# Processing Record 50 of Set 145 | caravelas
# Processing Record 50 of Set 146 | wattegama
# Processing Record 50 of Set 147 | howard springs
# Processing Record 50 of Set 148 | severnyy-kospashskiy
# Processing Record 50 of Set 149 | mar del plata
# Processing Record 50 of Set 150 | saldanha
# Processing Record 50 of Set 151 | santa maria
# Processing Record 50 of Set 152 | severo-kurilsk
# Processing Record 50 of Set 153 | xichang
# Processing Record 50 of Set 154 | klaksvik
# Processing Record 50 of Set 155 | champerico
# Processing Record 50 of Set 156 | sistranda
# Processing Record 50 of Set 157 | itajuba
# Processing Record 50 of Set 158 | prince rupert
# Processing Record 50 of Set 159 | orlik
# Processing Record 50 of Set 160 | inhambane
# Processing Record 50 of Set 161 | bonthe
# Processing Record 50 of Set 162 | jardim
# Processing Record 50 of Set 163 | izvestkovyy
# Processing Record 50 of Set 164 | longyearbyen
# Processing Record 50 of Set 165 | qaqortoq
# Processing Record 50 of Set 166 | manakara
# Processing Record 50 of Set 167 | kamen-rybolov
# City not found. Skipping...
# Processing Record 50 of Set 168 | pacific grove
# Processing Record 50 of Set 169 | broken hill
# Processing Record 50 of Set 170 | aripuana
# Processing Record 50 of Set 171 | dakar
# Processing Record 50 of Set 172 | tiksi
# Processing Record 50 of Set 173 | zhanaozen
# Processing Record 50 of Set 174 | buchanan
# City not found. Skipping...
# Processing Record 50 of Set 175 | powell river
# Processing Record 50 of Set 176 | la ronge
# Processing Record 50 of Set 177 | udachnyy
# Processing Record 50 of Set 178 | port macquarie
# Processing Record 50 of Set 179 | tura
# Processing Record 50 of Set 180 | roseau
# City not found. Skipping...
# Processing Record 50 of Set 181 | languyan
# Processing Record 50 of Set 182 | sao joao da barra
# Processing Record 50 of Set 183 | lesosibirsk
# Processing Record 50 of Set 184 | buraydah
# Processing Record 50 of Set 185 | luancheng
# Processing Record 50 of Set 186 | nampula
# Processing Record 50 of Set 187 | tapiramuta
# Processing Record 50 of Set 188 | stepnyak
# Processing Record 50 of Set 189 | sinnamary
# Processing Record 50 of Set 190 | dunedin
# Processing Record 50 of Set 191 | nikolskoye
# Processing Record 50 of Set 192 | kloulklubed
# City not found. Skipping...
# Processing Record 50 of Set 193 | vila franca do campo
# Processing Record 50 of Set 194 | great bend
# Processing Record 50 of Set 195 | nerchinskiy zavod
# Processing Record 50 of Set 196 | puerto escondido
# Processing Record 50 of Set 197 | north bay
# Processing Record 50 of Set 198 | ratodero
# Processing Record 50 of Set 199 | upernavik
# Processing Record 50 of Set 200 | coquimbo
# Processing Record 50 of Set 201 | pevek
# Processing Record 50 of Set 202 | iqaluit
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 203 | plettenberg bay
# Processing Record 50 of Set 204 | giaginskaya
# City not found. Skipping...
# Processing Record 50 of Set 205 | souillac
# Processing Record 50 of Set 206 | clyde river
# Processing Record 50 of Set 207 | sandnessjoen
# Processing Record 50 of Set 208 | fonte boa
# Processing Record 50 of Set 209 | inongo
# Processing Record 50 of Set 210 | bafoulabe
# Processing Record 50 of Set 211 | porto walter
# Processing Record 50 of Set 212 | san cristobal
# Processing Record 50 of Set 213 | mirador
# Processing Record 50 of Set 214 | mende
# Processing Record 50 of Set 215 | jamui
# City not found. Skipping...
# Processing Record 50 of Set 216 | soe
# Processing Record 50 of Set 217 | nongpoh
# Processing Record 50 of Set 218 | wajir
# City not found. Skipping...
# Processing Record 50 of Set 219 | rabak
# Processing Record 50 of Set 220 | esperance
# Processing Record 50 of Set 221 | shafranovo
# Processing Record 50 of Set 222 | kaminokawa
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 223 | fuji
# Processing Record 50 of Set 224 | sur
# Processing Record 50 of Set 225 | pueblo
# Processing Record 50 of Set 226 | sarangani
# Processing Record 50 of Set 227 | nurota
# Processing Record 50 of Set 228 | rochester
# Processing Record 50 of Set 229 | bako
# Processing Record 50 of Set 230 | mareeba
# Processing Record 50 of Set 231 | dalvik
# Processing Record 50 of Set 232 | manoel urbano
# Processing Record 50 of Set 233 | sovetskaya gavan
# City not found. Skipping...
# Processing Record 50 of Set 234 | batemans bay
# Processing Record 50 of Set 235 | ulaangom
# Processing Record 50 of Set 236 | alta floresta
# Processing Record 50 of Set 237 | conceicao do araguaia
# Processing Record 50 of Set 238 | kaitangata
# Processing Record 50 of Set 239 | muli
# Processing Record 50 of Set 240 | urzhum
# Processing Record 50 of Set 241 | labuhan
# Processing Record 50 of Set 242 | sesheke
# Processing Record 50 of Set 243 | sirjan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 244 | scarborough
# Processing Record 50 of Set 245 | santa isabel do rio negro
# Processing Record 50 of Set 246 | camopi
# Processing Record 50 of Set 247 | sao filipe
# Processing Record 50 of Set 248 | maceio
# Processing Record 50 of Set 249 | samarai
# Processing Record 50 of Set 250 | madarounfa
# Processing Record 50 of Set 251 | athabasca
# Processing Record 50 of Set 252 | sortland
# Processing Record 50 of Set 253 | kamaishi
# Processing Record 50 of Set 254 | hovd
# City not found. Skipping...
# Processing Record 50 of Set 255 | lavrentiya
# Processing Record 50 of Set 256 | yuci
# Processing Record 50 of Set 257 | nanakuli
# Processing Record 50 of Set 258 | sorland
# Processing Record 50 of Set 259 | beloha
# Processing Record 50 of Set 260 | north bend
# Processing Record 50 of Set 261 | sioux lookout
# Processing Record 50 of Set 262 | carauari
# City not found. Skipping...
# Processing Record 50 of Set 263 | tulsipur
# Processing Record 50 of Set 264 | saint george
# City not found. Skipping...
# Processing Record 50 of Set 265 | rio grande
# Processing Record 50 of Set 266 | mumford
# Processing Record 50 of Set 267 | shenjiamen
# Processing Record 50 of Set 268 | almendralejo
# Processing Record 50 of Set 269 | bintulu
# Processing Record 50 of Set 270 | aloleng
# Processing Record 50 of Set 271 | meadow lake
# Processing Record 50 of Set 272 | nouakchott
# Processing Record 50 of Set 273 | deputatskiy
# Processing Record 50 of Set 274 | cabatuan
# Processing Record 50 of Set 275 | oros
# Processing Record 50 of Set 276 | santa fe
# Processing Record 50 of Set 277 | shishou
# Processing Record 50 of Set 278 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 279 | cap malheureux
# City not found. Skipping...
# Processing Record 50 of Set 280 | luderitz
# Processing Record 50 of Set 281 | svetlaya
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 282 | tshikapa
# Processing Record 50 of Set 283 | laguna
# Processing Record 50 of Set 284 | bereda
# Processing Record 50 of Set 285 | buturlinovka
# Processing Record 50 of Set 286 | markova
# Processing Record 50 of Set 287 | mount isa
# Processing Record 50 of Set 288 | warrington
# Processing Record 50 of Set 289 | nemuro
# Processing Record 50 of Set 290 | luanda
# Processing Record 50 of Set 291 | kahului
# City not found. Skipping...
# Processing Record 50 of Set 292 | coachella
# Processing Record 50 of Set 293 | suntar
# Processing Record 50 of Set 294 | kieta
# Processing Record 50 of Set 295 | ban nahin
# Processing Record 50 of Set 296 | nabire
# Processing Record 50 of Set 297 | silves
# Processing Record 50 of Set 298 | maniitsoq
# Processing Record 50 of Set 299 | olinda
# Processing Record 50 of Set 300 | okhotsk
# Processing Record 50 of Set 301 | hamilton
# Processing Record 50 of Set 302 | phan thiet
# Processing Record 50 of Set 303 | hobyo
# Processing Record 50 of Set 304 | saint-francois
# Processing Record 50 of Set 305 | mao
# Processing Record 50 of Set 306 | sainte-savine
# City not found. Skipping...
# Processing Record 50 of Set 307 | sao joao nepomuceno
# Processing Record 50 of Set 308 | freeport
# Processing Record 50 of Set 309 | mwene-ditu
# Processing Record 50 of Set 310 | la rioja
# Processing Record 50 of Set 311 | santo angelo
# Processing Record 50 of Set 312 | muisne
# Processing Record 50 of Set 313 | moratuwa
# Processing Record 50 of Set 314 | sitka
# Processing Record 50 of Set 315 | korkino
# Processing Record 50 of Set 316 | curvelo
# Processing Record 50 of Set 317 | huaraz
# Processing Record 50 of Set 318 | waharoa
# Processing Record 50 of Set 319 | ambunti
# Processing Record 50 of Set 320 | caucaia
# Processing Record 50 of Set 321 | antibes
# Processing Record 50 of Set 322 | darnah
# Processing Record 50 of Set 323 | rio gallegos
# Processing Record 50 of Set 324 | charters towers
# Processing Record 50 of Set 325 | puerto lumbreras
# Processing Record 50 of Set 326 | cortez
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 327 | ruthin
# Processing Record 50 of Set 328 | alice town
# Processing Record 50 of Set 329 | tevriz
# Processing Record 50 of Set 330 | yurino
# Processing Record 50 of Set 331 | hami
# Processing Record 50 of Set 332 | san carlos de bariloche
# City not found. Skipping...
# Processing Record 50 of Set 333 | buin
# Processing Record 50 of Set 334 | hasaki
# Processing Record 50 of Set 335 | kijang
# Processing Record 50 of Set 336 | hearst
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 337 | mahibadhoo
# Processing Record 50 of Set 338 | santa cruz
# Processing Record 50 of Set 339 | jaguey grande
# Processing Record 50 of Set 340 | adrar
# Processing Record 50 of Set 341 | wembley
# Processing Record 50 of Set 342 | zhezkazgan
# City not found. Skipping...
# Processing Record 50 of Set 343 | hommersak
# Processing Record 50 of Set 344 | ust-kan
# Processing Record 50 of Set 345 | qiongshan
# Processing Record 50 of Set 346 | ballina
# Processing Record 50 of Set 347 | elk city
# Processing Record 50 of Set 348 | audru
# Processing Record 50 of Set 349 | maldonado
# Processing Record 50 of Set 350 | saint-joseph
# Processing Record 50 of Set 351 | verkhnyaya inta
# Processing Record 50 of Set 352 | khash
# Processing Record 50 of Set 353 | tadine
# Processing Record 50 of Set 354 | batouri
# Processing Record 50 of Set 355 | preobrazheniye
# Processing Record 50 of Set 356 | swift current
# Processing Record 50 of Set 357 | portland
# Processing Record 50 of Set 358 | kendari
# Processing Record 50 of Set 359 | grand gaube
# Processing Record 50 of Set 360 | meulaboh
# Processing Record 50 of Set 361 | san lorenzo
# City not found. Skipping...
# Processing Record 50 of Set 362 | nizhniy kuranakh
# Processing Record 50 of Set 363 | saint-augustin
# City not found. Skipping...
# Processing Record 50 of Set 364 | bayir
# Processing Record 50 of Set 365 | seoul
# Processing Record 50 of Set 366 | leningradskiy
# Processing Record 50 of Set 367 | ornskoldsvik
# Processing Record 50 of Set 368 | entre rios
# Processing Record 50 of Set 369 | geraldton
# Processing Record 50 of Set 370 | asyut
# Processing Record 50 of Set 371 | oriximina
# Processing Record 50 of Set 372 | mamallapuram
# Processing Record 50 of Set 373 | bathsheba
# City not found. Skipping...
# Processing Record 50 of Set 374 | narsaq
# Processing Record 50 of Set 375 | saint-pierre
# Processing Record 50 of Set 376 | palmer
# Processing Record 50 of Set 377 | forbes
# Processing Record 50 of Set 378 | sol-iletsk
# Processing Record 50 of Set 379 | usak
# Processing Record 50 of Set 380 | fortuna
# Processing Record 50 of Set 381 | adre
# Processing Record 50 of Set 382 | vrangel
# City not found. Skipping...
# Processing Record 50 of Set 383 | jaguaruna
# City not found. Skipping...
# Processing Record 50 of Set 384 | cockburn town
# Processing Record 50 of Set 385 | uruana
# Processing Record 50 of Set 386 | yaan
# Processing Record 50 of Set 387 | visby
# Processing Record 50 of Set 388 | arroyo
# Processing Record 50 of Set 389 | margate
# Processing Record 50 of Set 390 | paramonga
# Processing Record 50 of Set 391 | praia da vitoria
# Processing Record 50 of Set 392 | fare
# Processing Record 50 of Set 393 | dongsheng
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 394 | beyneu
# Processing Record 50 of Set 395 | tautira
# City not found. Skipping...
# Processing Record 50 of Set 396 | muyezerskiy
# Processing Record 50 of Set 397 | denison
# Processing Record 50 of Set 398 | gombe
# Processing Record 50 of Set 399 | karratha
# Processing Record 50 of Set 400 | marrakesh
# Processing Record 50 of Set 401 | kropotkin
# Processing Record 50 of Set 402 | the valley
# Processing Record 50 of Set 403 | grand-santi
# Processing Record 50 of Set 404 | lima
# Processing Record 50 of Set 405 | sobolevo
# Processing Record 50 of Set 406 | nago
# Processing Record 50 of Set 407 | katherine
# Processing Record 50 of Set 408 | urgut
# Processing Record 50 of Set 409 | roebourne
# Processing Record 50 of Set 410 | roma
# Processing Record 50 of Set 411 | whitehorse
# Processing Record 50 of Set 412 | tual
# Processing Record 50 of Set 413 | yeppoon
# Processing Record 50 of Set 414 | maiduguri
# City not found. Skipping...
# Processing Record 50 of Set 415 | porto novo
# Processing Record 50 of Set 416 | lafiagi
# Processing Record 50 of Set 417 | touros
# Processing Record 50 of Set 418 | kutum
# Processing Record 50 of Set 419 | sandovo
# Processing Record 50 of Set 420 | wick
# Processing Record 50 of Set 421 | banamba
# Processing Record 50 of Set 422 | victor harbor
# Processing Record 50 of Set 423 | alamogordo
# Processing Record 50 of Set 424 | camargo
# Processing Record 50 of Set 425 | holzgerlingen
# City not found. Skipping...
# Processing Record 50 of Set 426 | esso
# Processing Record 50 of Set 427 | deneysville
# Processing Record 50 of Set 428 | swan hill
# City not found. Skipping...
# Processing Record 50 of Set 429 | ossora
# Processing Record 50 of Set 430 | montes claros
# Processing Record 50 of Set 431 | teya
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 432 | husavik
# Processing Record 50 of Set 433 | la cumbre
# Processing Record 50 of Set 434 | barahona
# Processing Record 50 of Set 435 | igrim
# Processing Record 50 of Set 436 | bangolo
# City not found. Skipping...
# Processing Record 50 of Set 437 | cabedelo
# Processing Record 50 of Set 438 | killybegs
# Processing Record 50 of Set 439 | san francisco
# Processing Record 50 of Set 440 | moerai
# City not found. Skipping...
# Processing Record 50 of Set 441 | yumen
# City not found. Skipping...
# Processing Record 50 of Set 442 | constitucion
# Processing Record 50 of Set 443 | minas
# Processing Record 50 of Set 444 | araouane
# Processing Record 50 of Set 445 | soure
# Processing Record 50 of Set 446 | buala
# Processing Record 50 of Set 447 | norman wells
# Processing Record 50 of Set 448 | mogadishu
# Processing Record 50 of Set 449 | kosikha
# Processing Record 50 of Set 450 | ilam
# Processing Record 50 of Set 451 | linjiang
# Processing Record 50 of Set 452 | belyy yar
# City not found. Skipping...
# Processing Record 50 of Set 453 | ponta delgada
# City not found. Skipping...
# Processing Record 50 of Set 454 | thibodaux
# Processing Record 50 of Set 455 | borba
# Processing Record 50 of Set 456 | arman
# Processing Record 50 of Set 457 | makasar
# Processing Record 50 of Set 458 | mega
# Processing Record 50 of Set 459 | sumbe
# Processing Record 50 of Set 460 | necochea
# Processing Record 50 of Set 461 | linden
# City not found. Skipping...
# Processing Record 50 of Set 462 | baghdad
# Processing Record 50 of Set 463 | gamba
# Processing Record 50 of Set 464 | atambua
# Processing Record 50 of Set 465 | tezu
# Processing Record 50 of Set 466 | ola

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
